# %%
import socket
from time import sleep

# %%
# change port if its occupied already
host = 'localhost'
port = 9990

# %%
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((host, port))
s.listen(1)

# %%
count = 0
while True:
    print('\nPushing data at host =',host , port)
    conn, addr = s.accept()
    print('\nConnected by', addr)
    try:
        print('\nReading dataset...\n')
        with open('./datasets/test.csv') as f:
            for line in f:
                out = line.encode('utf-8')
                print('Sending records',line)
                conn.send(out)
                sleep(1)
                count += 1
                if count == 48 : 
                    break
            print('End Of Streaming.')
            break
    except socket.error:
        print ('socket error \n')
conn.close()
# Out:
# Pushing data at host = localhost 9990
#
# Connected by ('127.0.0.1', 50834)
#
# Reading dataset...
#
# Sending records BRFSS|%|AgeAdjPrev|1.2|0.9|1.8|CKD|CKD3_0|16|GENDER|GENM|43.68263|-114.36373
#
# Sending records BRFSS|%|AgeAdjPrev|1.3|1.0|1.8|CKD|CKD3_0|33|GENDER|GENM|43.65595|-71.50036
#
# Sending records BRFSS|%|AgeAdjPrev|2.2|1.7|2.9|ALC|ALC5_1|40|GENDER|GENF|35.47203|-97.52107
#
# Sending records BRFSS|%|AgeAdjPrev|1.8|1.0|3.2|ALC|ALC5_1|12|RACE|BLK|28.932041|-81.92896
#
# Sending records BRFSS|%|AgeAdjPrev|5.6|4.4|6.9|AST|AST1_1|28|GENDER|GENM|32.74551|-89.53803
#
# Sending records BRFSS|%|AgeAdjPrev|5.6|4.4|7.2|AST|AST1_1|66|OVERALL|OVR|13.444304|144.79373
#
# Sending records BRFSS|%|AgeAdjPrev|5.7|4.1|7.9|ART|ART2_0|49|RACE|HIS|40.644188|-111.95225
#
# Sending records BRFSS|%|AgeAdjPrev|5.8|3.3|10.0|ART|ART2_0|51|RACE|HIS|38.908546|-77.24052
#
# Sending records BRFSS|%|AgeAdjPrev|76.9|62.1|87.1|CAN|CAN1_0|53|RACE|MRC|47.522278|-120.47001
#
# Sending records BRFSS|%|AgeAdjPrev|76.9|73.9|79.5|CAN|CAN1_0|47|OVERALL|OVR|35.68094|-85.77449
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|50.6|49.7|51.4|CVD|CVD1_4|12|OVERALL|OVR|28.932041|-81.92896
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|50.8|39.8|63.8|CVD|CVD1_3|4|RACE|API|34.86597|-111.76381
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|162.7|149.9|175.6|COPD|COPD1_2|45|RACE|BLK|33.99882|-81.04537
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|162.4|149.5|175.2|COPD|COPD1_2|22|RACE|BLK|31.31266|-92.44568
#
# Sending records BRFSS|Number|AgeAdjMean|3.7|3.1|4.4|OVC|OVC7_1|12|RACE|BLK|28.932041|-81.92896
#
# Sending records BRFSS|Number|AgeAdjMean|3.7|3.4|3.9|OVC|OVC7_1|36|GENDER|GENF|42.827|-75.54397
#
# Sending records BRFSS|Number|CrdMean|1.4|1.2|1.6|NPAW|NPAW4_2|4|RACE|HIS|33.291798|-112.429146
#
# Sending records BRFSS|Number|CrdMean|1.4|1.2|1.6|NPAW|NPAW4_2|44|RACE|BLK|41.70828|-71.52247
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|1.0|0.8|1.2|DIA|DIA1_2|6|RACE|HIS|37.63864|-121.0
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|1.0|0.8|1.3|DIA|DIA1_2|17|RACE|WHT|40.485012|-88.99771
#
# Sending records BRFSS|%|AgeAdjPrev|27.8|25.5|30.2|IMM|IMM1_0|72|GENDER|GENM|18.220833|-66.59015
#
# Sending records BRFSS|%|AgeAdjPrev|30.7|26.0|35.8|IMM|IMM1_0|5|RACE|BLK|34.74865|-92.27449
#
# Sending records BRFSS|%|CrdPrev|19.9|11.3|32.6|MTH|MTH2_0|26|RACE|MRC|42.279076|-83.33619
#
# Sending records BRFSS|%|CrdPrev|20.1|13.1|29.6|MTH|MTH2_0|17|RACE|HIS|40.485012|-88.99771
#
# Sending records NVSS|cases per 1,000,000|AgeAdjRate|5.2|3.6|7.4|AST|AST4_1|48|RACE|HIS|31.82724|-99.42677
#
# Sending records NVSS|cases per 1,000,000|AgeAdjRate|5.3|3.6|7.5|AST|AST4_1|51|RACE|WHT|37.54268|-78.45789
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|3.7|2.3|5.8|ALC|ALC6_0|48|RACE|API|31.82724|-99.42677
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|3.7|3.2|4.3|ALC|ALC6_0|6|RACE|API|37.63864|-121.0
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|22.1|15.7|30.2|CKD|CKD1_0|24|RACE|HIS|39.29058|-76.60926
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|22.9|18.6|27.3|CKD|CKD1_0|12|RACE|API|28.932041|-81.92896
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|28.1|20.1|38.3|COPD|COPD1_1|12|RACE|API|28.932041|-81.92896
#
# Sending records NVSS|cases per 100,000|AgeAdjRate|28.1|22.8|33.4|COPD|COPD1_1|36|RACE|API|42.827|-75.54397
#
# Sending records BRFSS|%|AgeAdjPrev|6.7|6.0|7.5|DIA|DIA2_1|30|RACE|WHT|47.06653|-109.42442
#
# Sending records BRFSS|%|AgeAdjPrev|6.7|6.0|7.6|DIA|DIA2_1|16|RACE|WHT|43.68263|-114.36373
#
# Sending records BRFSS|%|AgeAdjPrev|14.0|10.2|19.0|NPAW|NPAW1_1|51|RACE|OTH|37.54268|-78.45789
#
# Sending records BRFSS|%|AgeAdjPrev|14.0|12.5|15.6|NPAW|NPAW11_2|21|GENDER|GENF|31.31266|-92.44568
#
# Sending records BRFSS|%|AgeAdjPrev|31.4|28.5|34.5|IMM|IMM1_0|32|GENDER|GENF|36.07956|-115.09405
#
# Sending records BRFSS|%|AgeAdjPrev|31.4|28.9|34.0|IMM|IMM1_0|48|RACE|HIS|32.773205|-97.351654
#
# Sending records BRFSS|%|AgeAdjPrev|36.6|26.0|48.6|CVD|CVD9_1|56|GENDER|GENF|43.235542|-108.10983
#
# Sending records BRFSS|%|AgeAdjPrev|31.4|29.7|33.2|CVD|CVD5_0|38|OVERALL|OVR|47.47532|-100.11842
#
# Sending records BRFSS|%|CrdPrev|12.3|10.3|14.6|MTH|MTH2_0|36|OVERALL|OVR|40.98488|-72.61512
#
# Sending records BRFSS|%|CrdPrev|12.6|9.5|16.5|MTH|MTH2_0|22|RACE|BLK|31.31266|-92.44568
#
# Sending records BRFSS|%|AgeAdjMean|4.2|3.2|5.2|OVC|OVC7_2|5|RACE|BLK|34.74865|-92.27449
#
# Sending records BRFSS|%|AgeAdjMean|4.0|3.1|4.8|OVC|OVC7_2|30|RACE|OTH|47.06653|-109.42442
#
# Sending records BRFSS|%|AgeAdjPrev|8.4|6.8|10.3|ART|ART2_0|34|RACE|BLK|40.13057|-74.27369
#
# Sending records BRFSS|%|AgeAdjPrev|8.0|6.3|10.0|ART|ART5_0|42|OVERALL|OVR|40.015278|-75.13119
#
# Sending records BRFSS|%|CrdPrev|19.9|18.8|21.1|TOB|TOB1_2|42|OVERALL|OVR|40.79373|-77.8607
#
# Sending records BRFSS|%|CrdPrev|20.0|17.8|22.4|TOB|TOB1_2|35|RACE|HIS|34.52088|-106.24058
# End Of Streaming.

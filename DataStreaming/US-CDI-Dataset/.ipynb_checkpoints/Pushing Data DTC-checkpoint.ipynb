# %%
import socket
from time import sleep

# %%
# change port if its occupied already
host = 'localhost'
port = 9990

# %%
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((host, port))
s.listen(1)

# %%
count = 0
while True:
    print('\nPushing data at host =',host , port)
    conn, addr = s.accept()
    print('\nConnected by', addr)
    try:
        print('\nReading dataset...\n')
        with open('./datasets/test.csv') as f:
            for line in f:
                out = line.encode('utf-8')
                print('Sending records',line)
                conn.send(out)
                sleep(1)
            print('End Of Streaming.')
            break
    except socket.error:
        print ('socket error \n')
conn.close()
# Out:
# Pushing data at host = localhost 9990
#
# Connected by ('127.0.0.1', 55168)
#
# Reading dataset...
#
# Sending records 576489600.0|91.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 576525600.0|147.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 577800000.0|110.0|Pre-lunch blood glucose measurement|0.0
#
# socket error
#
#
# Pushing data at host = localhost 9990
#
# Connected by ('127.0.0.1', 55286)
#
# Reading dataset...
#
# Sending records 576489600.0|91.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 576525600.0|147.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 577800000.0|110.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 578131200.0|20.0|NPH insulin dose|1.0
#
# Sending records 578476800.0|20.0|NPH insulin dose|1.0
#
# Sending records 578649600.0|111.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 578995200.0|89.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 579182400.0|84.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 579204000.0|131.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 579340800.0|20.0|NPH insulin dose|1.0
#
# Sending records 579722400.0|124.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 580723200.0|116.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 580896000.0|20.0|NPH insulin dose|1.0
#
# Sending records 580982400.0|20.0|NPH insulin dose|1.0
#
# Sending records 581500800.0|67.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 581587200.0|20.0|NPH insulin dose|1.0
#
# Sending records 581673600.0|74.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 581688000.0|53.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 581846400.0|75.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 581860800.0|93.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 582055200.0|149.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 582105600.0|15.0|NPH insulin dose|1.0
#
# Sending records 582105600.0|119.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 582292800.0|98.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 582796800.0|12.0|NPH insulin dose|1.0
#
# Sending records 583070400.0|131.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 583416000.0|140.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 583610400.0|159.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 583920000.0|137.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 584179200.0|111.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 584647200.0|103.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 584798400.0|112.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 584956800.0|26.0|NPH insulin dose|1.0
#
# Sending records 585424800.0|138.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 585576000.0|122.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 585784800.0|62.0|Unspecified blood glucose measurement|0.0
#
# Sending records 585820800.0|12.0|NPH insulin dose|1.0
#
# Sending records 585907200.0|22.0|NPH insulin dose|1.0
#
# Sending records 585921600.0|126.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 586130400.0|203.0|Unspecified blood glucose measurement|0.0
#
# Sending records 586353600.0|119.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 586512000.0|22.0|NPH insulin dose|1.0
#
# Sending records 586512000.0|154.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 586562400.0|226.0|Unspecified blood glucose measurement|0.0
#
# Sending records 587217600.0|218.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 587980800.0|12.0|NPH insulin dose|1.0
#
# Sending records 588067200.0|22.0|NPH insulin dose|1.0
#
# Sending records 588412800.0|12.0|NPH insulin dose|1.0
#
# Sending records 588412800.0|22.0|NPH insulin dose|1.0
#
# Sending records 588412800.0|193.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 588427200.0|144.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 588463200.0|112.0|Unspecified blood glucose measurement|0.0
#
# Sending records 588931200.0|87.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 589104000.0|12.0|NPH insulin dose|1.0
#
# Sending records 589708800.0|107.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 590241600.0|200.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 590486400.0|12.0|NPH insulin dose|1.0
#
# Sending records 590572800.0|102.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 590832000.0|142.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 591019200.0|94.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 591213600.0|118.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 591264000.0|22.0|NPH insulin dose|1.0
#
# Sending records 591364800.0|97.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 591436800.0|114.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 591868800.0|22.0|NPH insulin dose|1.0
#
# Sending records 591904800.0|164.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 591991200.0|222.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 592005600.0|245.0|Unspecified blood glucose measurement|0.0
#
# Sending records 592300800.0|108.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 592315200.0|72.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 592387200.0|129.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 592401600.0|213.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 592423200.0|145.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 592473600.0|16.0|NPH insulin dose|1.0
#
# Sending records 592574400.0|134.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 592768800.0|6.0|Regular insulin dose|1.0
#
# Sending records 592768800.0|82.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 592783200.0|115.0|Unspecified blood glucose measurement|0.0
#
# Sending records 592992000.0|6.0|Regular insulin dose|1.0
#
# Sending records 593251200.0|157.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 593337600.0|6.0|Regular insulin dose|1.0
#
# Sending records 593769600.0|99.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 593992800.0|140.0|Unspecified blood glucose measurement|0.0
#
# Sending records 594288000.0|12.0|NPH insulin dose|1.0
#
# Sending records 594302400.0|75.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 594338400.0|147.0|Unspecified blood glucose measurement|0.0
#
# Sending records 594633600.0|6.0|Regular insulin dose|1.0
#
# Sending records 594669600.0|6.0|Regular insulin dose|1.0
#
# Sending records 594669600.0|127.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 595497600.0|123.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 596030400.0|142.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 596397600.0|136.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 596880000.0|12.0|NPH insulin dose|1.0
#
# Sending records 596880000.0|179.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 597067200.0|147.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 597484800.0|12.0|NPH insulin dose|1.0
#
# Sending records 597693600.0|102.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 597916800.0|12.0|NPH insulin dose|1.0
#
# Sending records 598125600.0|90.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 598435200.0|12.0|NPH insulin dose|1.0
#
# Sending records 598644000.0|120.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 598953600.0|12.0|NPH insulin dose|1.0
#
# Sending records 598968000.0|120.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 599508000.0|6.0|Regular insulin dose|1.0
#
# Sending records 599731200.0|6.0|Regular insulin dose|1.0
#
# Sending records 599904000.0|120.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 600026400.0|6.0|Regular insulin dose|1.0
#
# Sending records 600127200.0|114.0|Unspecified blood glucose measurement|0.0
#
# Sending records 600508800.0|16.0|NPH insulin dose|1.0
#
# Sending records 600544800.0|73.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 601646400.0|4.0|Regular insulin dose|1.0
#
# Sending records 601718400.0|16.0|NPH insulin dose|1.0
# Sending records 601804800.0|107.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 602323200.0|154.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 602335800.0|83.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 602496000.0|202.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 602618400.0|7.0|Regular insulin dose|1.0
#
# Sending records 602719200.0|2.0|Regular insulin dose|1.0
#
# Sending records 602892000.0|0.0|Regular insulin dose|1.0
#
# Sending records 602899200.0|45.0|Unspecified blood glucose measurement|0.0
#
# Sending records 603187200.0|15.0|UltraLente insulin dose|1.0
#
# Sending records 603324000.0|157.0|Unspecified blood glucose measurement|0.0
#
# Sending records 603360000.0|15.0|UltraLente insulin dose|1.0
#
# Sending records 603396000.0|5.0|Regular insulin dose|1.0
#
# Sending records 603496800.0|102.0|Unspecified blood glucose measurement|0.0
#
# Sending records 603532800.0|9.0|Regular insulin dose|1.0
#
# Sending records 603583200.0|170.0|Unspecified blood glucose measurement|0.0
#
# Sending records 603669600.0|112.0|Unspecified blood glucose measurement|0.0
#
# Sending records 603792000.0|202.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 603806400.0|2.0|Regular insulin dose|1.0
#
# Sending records 603878400.0|17.0|UltraLente insulin dose|1.0
#
# Sending records 603914400.0|3.0|Regular insulin dose|1.0
#
# Sending records 603963000.0|16.0|NPH insulin dose|1.0
#
# Sending records 603964800.0|133.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 603964800.0|245.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 604000800.0|72.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 604101600.0|117.0|Unspecified blood glucose measurement|0.0
#
# Sending records 604224000.0|4.0|Regular insulin dose|1.0
#
# Sending records 604238400.0|147.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 604292400.0|161.0|Unspecified blood glucose measurement|0.0
#
# Sending records 604346400.0|3.0|NPH insulin dose|1.0
#
# Sending records 604447200.0|82.0|Unspecified blood glucose measurement|0.0
#
# Sending records 604497600.0|62.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 604519200.0|140.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 604706400.0|142.0|Unspecified blood glucose measurement|0.0
#
# Sending records 604828800.0|3.0|Regular insulin dose|1.0
#
# Sending records 604864800.0|3.0|Regular insulin dose|1.0
#
# Sending records 604879200.0|60.0|Unspecified blood glucose measurement|0.0
#
# Sending records 605016000.0|2.0|Regular insulin dose|1.0
#
# Sending records 605016000.0|4.0|Regular insulin dose|1.0
#
# Sending records 605210400.0|4.0|Regular insulin dose|1.0
#
# Sending records 605296800.0|3.5|Regular insulin dose|1.0
#
# Sending records 605361600.0|199.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 605383200.0|203.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 605430000.0|103.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 605433600.0|87.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 605448000.0|4.0|Regular insulin dose|1.0
#
# Sending records 605448000.0|151.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 605466000.0|6.0|Regular insulin dose|1.0
#
# Sending records 605520000.0|225.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 605556000.0|4.0|Regular insulin dose|1.0
#
# Sending records 605606400.0|6.5|NPH insulin dose|1.0
#
# Sending records 605642400.0|129.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 605692800.0|4.5|Regular insulin dose|1.0
#
# Sending records 605692800.0|200.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 605707200.0|104.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 605728800.0|3.5|NPH insulin dose|1.0
#
# Sending records 605743200.0|125.0|Unspecified blood glucose measurement|0.0
#
# Sending records 605779200.0|8.0|Regular insulin dose|1.0
#
# Sending records 605793600.0|213.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 605952000.0|4.5|Regular insulin dose|1.0
#
# Sending records 605988000.0|4.5|Regular insulin dose|1.0
#
# Sending records 605991600.0|0.0|Typical meal ingestion|1.0
#
# Sending records 606038400.0|5.0|Regular insulin dose|1.0
#
# Sending records 606038400.0|221.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 606074400.0|7.0|NPH insulin dose|1.0
#
# Sending records 606160800.0|3.0|NPH insulin dose|1.0
#
# Sending records 606160800.0|4.5|Regular insulin dose|1.0
#
# Sending records 606211200.0|15.0|UltraLente insulin dose|1.0
#
# Sending records 606225600.0|155.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 606297600.0|7.5|NPH insulin dose|1.0
#
# Sending records 606348000.0|71.0|Unspecified blood glucose measurement|0.0
#
# Sending records 606348000.0|142.0|Unspecified blood glucose measurement|0.0
#
# Sending records 606484800.0|6.0|Regular insulin dose|1.0
#
# Sending records 606520800.0|120.0|Unspecified blood glucose measurement|0.0
#
# Sending records 606571200.0|4.0|Regular insulin dose|1.0
#
# Sending records 606592800.0|4.5|Regular insulin dose|1.0
#
# Sending records 606657600.0|210.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 606729600.0|3.0|Regular insulin dose|1.0
#
# Sending records 606729600.0|8.0|NPH insulin dose|1.0
#
# Sending records 607039200.0|207.0|Unspecified blood glucose measurement|0.0
#
# Sending records 607075200.0|5.0|Regular insulin dose|1.0
#
# Sending records 607075200.0|8.0|NPH insulin dose|1.0
#
# Sending records 607075200.0|15.0|UltraLente insulin dose|1.0
#
# Sending records 607075200.0|147.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 607197600.0|2.0|Regular insulin dose|1.0
#
# Sending records 607197600.0|4.0|NPH insulin dose|1.0
#
# Sending records 607197600.0|4.0|Regular insulin dose|1.0
#
# Sending records 607197600.0|6.0|Regular insulin dose|1.0
#
# Sending records 607284000.0|7.0|NPH insulin dose|1.0
#
# Sending records 607284000.0|10.0|Regular insulin dose|1.0
#
# Sending records 607298400.0|111.0|Unspecified blood glucose measurement|0.0
#
# Sending records 607370400.0|2.0|Regular insulin dose|1.0
#
# Sending records 607370400.0|5.0|Regular insulin dose|1.0
#
# Sending records 607417200.0|6.0|Regular insulin dose|1.0
#
# Sending records 607417200.0|104.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 607420800.0|33.0|NPH insulin dose|1.0
#
# Sending records 607435200.0|6.0|Regular insulin dose|1.0
#
# Sending records 607435200.0|345.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 607456800.0|210.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 607557600.0|168.0|Unspecified blood glucose measurement|0.0
#
# Sending records 607629600.0|4.0|NPH insulin dose|1.0
#
# Sending records 607629600.0|6.0|Regular insulin dose|1.0
#
# Sending records 607649400.0|92.0|Unspecified blood glucose measurement|0.0
#
# Sending records 607766400.0|33.0|NPH insulin dose|1.0
#
# Sending records 607780800.0|4.0|Regular insulin dose|1.0
#
# Sending records 607780800.0|153.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 607802400.0|4.0|NPH insulin dose|1.0
#
# Sending records 607816800.0|61.0|Unspecified blood glucose measurement|0.0
#
# Sending records 607888800.0|227.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 607953600.0|3.0|Regular insulin dose|1.0
#
# Sending records 607975200.0|64.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 608040000.0|151.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 608076000.0|131.0|Unspecified blood glucose measurement|0.0
#
# Sending records 608108400.0|16.0|NPH insulin dose|1.0
#
# Sending records 608112000.0|4.0|Regular insulin dose|1.0
#
# Sending records 608112000.0|8.0|NPH insulin dose|1.0
#
# Sending records 608148000.0|3.0|Regular insulin dose|1.0
#
# Sending records 608198400.0|33.0|NPH insulin dose|1.0
#
# Sending records 608234400.0|83.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 608284800.0|18.0|NPH insulin dose|1.0
#
# Sending records 608320800.0|7.0|NPH insulin dose|1.0
#
# Sending records 608335200.0|51.0|Unspecified blood glucose measurement|0.0
#
# Sending records 608407200.0|256.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 608472000.0|149.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 608475600.0|142.0|Pre-lunch blood glucose measurement|0.0
# Sending records 608508000.0|249.0|Unspecified blood glucose measurement|0.0
#
# Sending records 608544000.0|17.0|NPH insulin dose|1.0
#
# Sending records 608544000.0|307.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 608580000.0|5.0|Regular insulin dose|1.0
#
# Sending records 608630400.0|6.0|Regular insulin dose|1.0
#
# Sending records 608630400.0|17.0|NPH insulin dose|1.0
#
# Sending records 608644800.0|100.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 608666400.0|7.0|Regular insulin dose|1.0
#
# Sending records 608716800.0|3.0|Regular insulin dose|1.0
#
# Sending records 608716800.0|8.0|NPH insulin dose|1.0
#
# Sending records 608716800.0|138.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 608752800.0|192.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 608803200.0|316.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 608835600.0|6.0|Regular insulin dose|1.0
#
# Sending records 608839200.0|3.0|Regular insulin dose|1.0
#
# Sending records 608887800.0|133.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 608904000.0|5.0|Regular insulin dose|1.0
#
# Sending records 608907600.0|146.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 608925600.0|7.0|NPH insulin dose|1.0
#
# Sending records 608970000.0|25.0|UltraLente insulin dose|1.0
#
# Sending records 609013800.0|15.0|Regular insulin dose|1.0
#
# Sending records 609062400.0|6.0|Regular insulin dose|1.0
#
# Sending records 609100500.0|15.0|Regular insulin dose|1.0
#
# Sending records 609148800.0|33.0|NPH insulin dose|1.0
#
# Sending records 609235200.0|5.0|Regular insulin dose|1.0
#
# Sending records 609235200.0|13.0|UltraLente insulin dose|1.0
#
# Sending records 609249600.0|145.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 609271200.0|11.0|Regular insulin dose|1.0
#
# Sending records 609285600.0|70.0|Unspecified blood glucose measurement|0.0
#
# Sending records 609321600.0|13.0|UltraLente insulin dose|1.0
#
# Sending records 609321600.0|33.0|NPH insulin dose|1.0
#
# Sending records 609336000.0|80.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 609337800.0|8.0|Regular insulin dose|1.0
#
# Sending records 609357600.0|4.0|NPH insulin dose|1.0
#
# Sending records 609408000.0|187.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 609444000.0|7.0|NPH insulin dose|1.0
#
# Sending records 609445800.0|18.0|Regular insulin dose|1.0
#
# Sending records 609508800.0|3.0|Regular insulin dose|1.0
#
# Sending records 609530400.0|10.0|Regular insulin dose|1.0
#
# Sending records 609549600.0|0.0|More-than-usual meal ingestion|1.0
#
# Sending records 609580800.0|3.0|NPH insulin dose|1.0
#
# Sending records 609580800.0|18.0|NPH insulin dose|1.0
#
# Sending records 609580800.0|202.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 609595500.0|8.0|Regular insulin dose|1.0
#
# Sending records 609598800.0|4.0|Regular insulin dose|1.0
#
# Sending records 609616800.0|5.0|Regular insulin dose|1.0
#
# Sending records 609631200.0|161.0|Unspecified blood glucose measurement|0.0
#
# Sending records 609662400.0|306.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 609682500.0|6.0|Regular insulin dose|1.0
#
# Sending records 609703200.0|5.0|NPH insulin dose|1.0
#
# Sending records 609753600.0|7.0|Regular insulin dose|1.0
#
# Sending records 609789600.0|3.0|Regular insulin dose|1.0
#
# Sending records 609838500.0|222.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 609840000.0|18.0|NPH insulin dose|1.0
#
# Sending records 609876000.0|138.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 609876900.0|190.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 609926400.0|18.0|NPH insulin dose|1.0
#
# Sending records 609926400.0|184.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 609940800.0|126.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 609962400.0|3.0|Regular insulin dose|1.0
#
# Sending records 609962400.0|170.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610027200.0|3.0|Regular insulin dose|1.0
#
# Sending records 610027200.0|155.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610048800.0|6.0|NPH insulin dose|1.0
#
# Sending records 610048800.0|161.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610099200.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 610135200.0|6.0|NPH insulin dose|1.0
#
# Sending records 610135200.0|225.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610135200.0|302.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610185600.0|18.0|NPH insulin dose|1.0
#
# Sending records 610200000.0|101.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610221600.0|8.0|Regular insulin dose|1.0
#
# Sending records 610272000.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 610272000.0|33.0|NPH insulin dose|1.0
#
# Sending records 610286400.0|184.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610287000.0|139.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610308000.0|1.0|Regular insulin dose|1.0
#
# Sending records 610308000.0|4.0|Regular insulin dose|1.0
#
# Sending records 610358400.0|1.0|Regular insulin dose|1.0
#
# Sending records 610374600.0|4.0|Regular insulin dose|1.0
#
# Sending records 610394400.0|6.0|NPH insulin dose|1.0
#
# Sending records 610394400.0|221.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610408800.0|77.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610411800.0|168.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610463700.0|188.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610495200.0|142.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610531800.0|19.0|Regular insulin dose|1.0
#
# Sending records 610567200.0|10.0|Regular insulin dose|1.0
#
# Sending records 610569300.0|123.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610581600.0|96.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610612500.0|15.0|Regular insulin dose|1.0
#
# Sending records 610612500.0|28.0|UltraLente insulin dose|1.0
#
# Sending records 610653600.0|4.0|Regular insulin dose|1.0
#
# Sending records 610653600.0|6.0|NPH insulin dose|1.0
#
# Sending records 610668000.0|207.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610668000.0|252.0|Unspecified blood glucose measurement|0.0
#
# Sending records 610699200.0|145.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 610704000.0|33.0|NPH insulin dose|1.0
#
# Sending records 610718700.0|6.0|Regular insulin dose|1.0
#
# Sending records 610740000.0|4.0|NPH insulin dose|1.0
#
# Sending records 610740000.0|242.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 610790400.0|74.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 610790400.0|316.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 610804800.0|66.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610804800.0|207.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 610826400.0|4.0|Regular insulin dose|1.0
#
# Sending records 610872000.0|28.0|UltraLente insulin dose|1.0
#
# Sending records 610876800.0|93.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 610891200.0|3.0|Regular insulin dose|1.0
#
# Sending records 610977600.0|4.0|Regular insulin dose|1.0
#
# Sending records 611049600.0|7.0|Regular insulin dose|1.0
#
# Sending records 611051100.0|305.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 611136600.0|18.0|Regular insulin dose|1.0
#
# Sending records 611150400.0|2.0|Regular insulin dose|1.0
#
# Sending records 611172000.0|6.0|Regular insulin dose|1.0
#
# Sending records 611188800.0|263.0|Unspecified blood glucose measurement|0.0
#
# Sending records 611236800.0|83.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 611308800.0|172.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 611359200.0|218.0|Unspecified blood glucose measurement|0.0
#
# Sending records 611395200.0|155.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 611409600.0|2.0|Regular insulin dose|1.0
#
# Sending records 611460000.0|0.0|More-than-usual meal ingestion|1.0
#
# Sending records 611481600.0|210.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 611520600.0|220.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 611562900.0|92.0|Pre-breakfast blood glucose measurement|0.0
# Sending records 611606700.0|194.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 611649000.0|13.0|Regular insulin dose|1.0
#
# Sending records 611649000.0|59.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 611658600.0|17.0|Regular insulin dose|1.0
#
# Sending records 611719200.0|44.0|Unspecified blood glucose measurement|0.0
#
# Sending records 611722800.0|4.0|Regular insulin dose|1.0
#
# Sending records 611776800.0|157.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 611842500.0|8.0|Regular insulin dose|1.0
#
# Sending records 611913600.0|6.0|Regular insulin dose|1.0
#
# Sending records 611913600.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 611994900.0|246.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 612086400.0|5.0|Regular insulin dose|1.0
#
# Sending records 612086400.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 612120900.0|108.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 612188400.0|60.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 612241200.0|0.0|Hypoglycemic symptoms|1.0
#
# Sending records 612295200.0|4.0|Regular insulin dose|1.0
#
# Sending records 612314400.0|353.0|Unspecified blood glucose measurement|0.0
#
# Sending records 612362700.0|146.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 612379500.0|17.0|Regular insulin dose|1.0
#
# Sending records 612396000.0|367.0|Unspecified blood glucose measurement|0.0
#
# Sending records 612432000.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 612442800.0|67.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 612459300.0|210.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 612516600.0|129.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 612518400.0|312.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 612565200.0|6.0|Regular insulin dose|1.0
#
# Sending records 612598500.0|105.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 612603000.0|6.0|Regular insulin dose|1.0
#
# Sending records 612604800.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 612640800.0|56.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 612642600.0|6.0|Regular insulin dose|1.0
#
# Sending records 612705600.0|336.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 612707400.0|133.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 612727200.0|147.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 612777600.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 612813000.0|225.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 612830400.0|349.0|Unspecified blood glucose measurement|0.0
#
# Sending records 612864000.0|12.0|UltraLente insulin dose|1.0
#
# Sending records 612868800.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 613051200.0|6.0|Regular insulin dose|1.0
#
# Sending records 613051200.0|181.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 613065600.0|275.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 613072800.0|3.0|Regular insulin dose|1.0
#
# Sending records 613072800.0|46.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 613123200.0|9.0|Regular insulin dose|1.0
#
# Sending records 613209600.0|81.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 613245600.0|4.0|Regular insulin dose|1.0
#
# Sending records 613260000.0|146.0|Unspecified blood glucose measurement|0.0
#
# Sending records 613359900.0|0.0|More-than-usual meal ingestion|1.0
#
# Sending records 613419000.0|77.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 613470300.0|17.0|Regular insulin dose|1.0
#
# Sending records 613470300.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 613501200.0|6.0|Regular insulin dose|1.0
#
# Sending records 613556100.0|266.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 613590900.0|200.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 613639800.0|16.0|NPH insulin dose|1.0
#
# Sending records 613764900.0|187.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 613828800.0|6.0|Regular insulin dose|1.0
#
# Sending records 613924200.0|154.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 614002200.0|6.0|Regular insulin dose|1.0
#
# Sending records 614109600.0|266.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 614343600.0|125.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 614414400.0|222.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 614430600.0|267.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 614585400.0|199.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 614605200.0|9.0|Regular insulin dose|1.0
#
# Sending records 614849400.0|6.0|Regular insulin dose|1.0
#
# Sending records 614849400.0|109.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 615039300.0|4.0|Regular insulin dose|1.0
#
# Sending records 615108600.0|16.0|NPH insulin dose|1.0
#
# Sending records 615125100.0|6.0|Regular insulin dose|1.0
#
# Sending records 615234600.0|62.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 615286800.0|140.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 615287700.0|158.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 615364200.0|6.0|Regular insulin dose|1.0
#
# Sending records 615451500.0|13.0|Regular insulin dose|1.0
#
# Sending records 615492000.0|92.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 615544800.0|204.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 615579600.0|16.0|Regular insulin dose|1.0
#
# Sending records 615594600.0|160.0|Unspecified blood glucose measurement|0.0
#
# Sending records 615624600.0|16.0|Regular insulin dose|1.0
#
# Sending records 615624600.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 615627000.0|75.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 615711600.0|16.0|NPH insulin dose|1.0
#
# Sending records 615817200.0|6.0|Regular insulin dose|1.0
#
# Sending records 615841200.0|6.0|Regular insulin dose|1.0
#
# Sending records 615857400.0|191.0|Unspecified blood glucose measurement|0.0
#
# Sending records 615918600.0|6.0|Regular insulin dose|1.0
#
# Sending records 615992400.0|4.0|Regular insulin dose|1.0
#
# Sending records 616014300.0|172.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 616075500.0|142.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 616143600.0|6.0|Regular insulin dose|1.0
#
# Sending records 616159800.0|72.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 616183800.0|266.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 616228500.0|260.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 616267800.0|84.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 616315200.0|13.0|Regular insulin dose|1.0
#
# Sending records 616315200.0|178.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 616316400.0|102.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 616374000.0|128.0|Unspecified blood glucose measurement|0.0
#
# Sending records 616421400.0|114.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 616512600.0|8.0|Regular insulin dose|1.0
#
# Sending records 616528800.0|14.0|Regular insulin dose|1.0
#
# Sending records 616548600.0|237.0|Unspecified blood glucose measurement|0.0
#
# Sending records 616629600.0|163.0|Unspecified blood glucose measurement|0.0
#
# Sending records 616681800.0|4.0|Regular insulin dose|1.0
#
# Sending records 616717800.0|86.0|Unspecified blood glucose measurement|0.0
#
# Sending records 616872600.0|51.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 616920000.0|242.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 616921200.0|103.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 617006400.0|15.0|Regular insulin dose|1.0
#
# Sending records 617026500.0|200.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617054400.0|151.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 617067300.0|225.0|Unspecified blood glucose measurement|0.0
#
# Sending records 617266800.0|147.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 617295600.0|62.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617394600.0|6.0|Regular insulin dose|1.0
#
# Sending records 617437800.0|16.0|NPH insulin dose|1.0
#
# Sending records 617437800.0|214.0|Pre-breakfast blood glucose measurement|0.0
# Sending records 617454000.0|144.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617473800.0|6.0|Regular insulin dose|1.0
#
# Sending records 617554800.0|92.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617554800.0|203.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617720400.0|135.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 617743500.0|19.0|Regular insulin dose|1.0
#
# Sending records 617747400.0|194.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 617762400.0|0.0|More-than-usual meal ingestion|1.0
#
# Sending records 617762400.0|34.0|Unspecified blood glucose measurement|0.0
#
# Sending records 617788800.0|297.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 617806800.0|4.0|Regular insulin dose|1.0
#
# Sending records 618161400.0|337.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 618396000.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 618406200.0|239.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 618444000.0|87.0|Unspecified blood glucose measurement|0.0
#
# Sending records 618475800.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 618648000.0|236.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 618687900.0|18.0|Regular insulin dose|1.0
#
# Sending records 618861600.0|18.0|Regular insulin dose|1.0
#
# Sending records 618947100.0|19.0|Regular insulin dose|1.0
#
# Sending records 619166100.0|15.0|Regular insulin dose|1.0
#
# Sending records 619223700.0|229.0|Unspecified blood glucose measurement|0.0
#
# Sending records 619255800.0|16.0|NPH insulin dose|1.0
#
# Sending records 619255800.0|189.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 619277400.0|4.0|Regular insulin dose|1.0
#
# Sending records 619294800.0|17.0|Regular insulin dose|1.0
#
# Sending records 619308000.0|110.0|Unspecified blood glucose measurement|0.0
#
# Sending records 619363800.0|4.0|Regular insulin dose|1.0
#
# Sending records 619426800.0|169.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 619444800.0|4.0|Regular insulin dose|1.0
#
# Sending records 619468200.0|180.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 619668000.0|76.0|Unspecified blood glucose measurement|0.0
#
# Sending records 619684200.0|30.0|UltraLente insulin dose|1.0
#
# Sending records 619771200.0|172.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 619963800.0|6.0|Regular insulin dose|1.0
#
# Sending records 619963800.0|106.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 620001000.0|123.0|Unspecified blood glucose measurement|0.0
#
# Sending records 620118000.0|6.0|Regular insulin dose|1.0
#
# Sending records 620220600.0|107.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 620247000.0|14.0|Regular insulin dose|1.0
#
# Sending records 620260500.0|249.0|Unspecified blood glucose measurement|0.0
#
# Sending records 620309100.0|223.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 620322600.0|197.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 620548500.0|16.0|Regular insulin dose|1.0
#
# Sending records 620899200.0|14.0|Regular insulin dose|1.0
#
# Sending records 620935200.0|68.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 621000000.0|122.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 621021600.0|12.0|Regular insulin dose|1.0
#
# Sending records 621036000.0|160.0|Unspecified blood glucose measurement|0.0
#
# Sending records 621108000.0|12.0|Regular insulin dose|1.0
#
# Sending records 621158400.0|18.0|NPH insulin dose|1.0
#
# Sending records 621244800.0|10.0|Regular insulin dose|1.0
#
# Sending records 621367200.0|12.0|Regular insulin dose|1.0
#
# Sending records 621417600.0|18.0|NPH insulin dose|1.0
#
# Sending records 621588600.0|196.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 621618300.0|4.0|Regular insulin dose|1.0
#
# Sending records 621761400.0|6.0|Regular insulin dose|1.0
#
# Sending records 621799200.0|100.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 621862200.0|50.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 621936000.0|18.0|NPH insulin dose|1.0
#
# Sending records 622045800.0|4.0|Regular insulin dose|1.0
#
# Sending records 622247400.0|142.0|Unspecified blood glucose measurement|0.0
#
# Sending records 622569600.0|6.0|Regular insulin dose|1.0
#
# Sending records 622591200.0|152.0|Unspecified blood glucose measurement|0.0
#
# Sending records 622627200.0|18.0|NPH insulin dose|1.0
#
# Sending records 622641600.0|12.0|Regular insulin dose|1.0
#
# Sending records 622713600.0|167.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 622729800.0|64.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 622908000.0|92.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 622969200.0|16.0|NPH insulin dose|1.0
#
# Sending records 623008800.0|43.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 623255400.0|108.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 623273400.0|6.0|Regular insulin dose|1.0
#
# Sending records 623332800.0|16.0|Regular insulin dose|1.0
#
# Sending records 623404800.0|10.0|Regular insulin dose|1.0
#
# Sending records 623574000.0|175.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 623836800.0|18.0|NPH insulin dose|1.0
#
# Sending records 624024000.0|10.0|Regular insulin dose|1.0
#
# Sending records 624024000.0|48.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624096000.0|106.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 624110400.0|59.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624112200.0|104.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624137400.0|72.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 624182400.0|10.0|Regular insulin dose|1.0
#
# Sending records 624195000.0|169.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624283200.0|284.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624351600.0|6.0|Regular insulin dose|1.0
#
# Sending records 624355200.0|10.0|Regular insulin dose|1.0
#
# Sending records 624355200.0|18.0|NPH insulin dose|1.0
#
# Sending records 624441600.0|18.0|NPH insulin dose|1.0
#
# Sending records 624564000.0|10.0|Regular insulin dose|1.0
#
# Sending records 624578400.0|170.0|Unspecified blood glucose measurement|0.0
#
# Sending records 624614400.0|10.0|Regular insulin dose|1.0
#
# Sending records 624614400.0|124.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 624650400.0|10.0|Regular insulin dose|1.0
#
# Sending records 624700800.0|110.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 624715200.0|10.0|Regular insulin dose|1.0
#
# Sending records 624801600.0|10.0|Regular insulin dose|1.0
#
# Sending records 624837600.0|14.0|Regular insulin dose|1.0
#
# Sending records 624837600.0|99.0|Unspecified blood glucose measurement|0.0
#
# Sending records 624873600.0|10.0|Regular insulin dose|1.0
#
# Sending records 624888000.0|169.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 624911400.0|6.0|Regular insulin dose|1.0
#
# Sending records 624958200.0|93.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 625010400.0|118.0|Unspecified blood glucose measurement|0.0
#
# Sending records 625062600.0|4.0|Regular insulin dose|1.0
#
# Sending records 625168800.0|10.0|Regular insulin dose|1.0
#
# Sending records 625168800.0|165.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 625183200.0|175.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 625183200.0|182.0|Unspecified blood glucose measurement|0.0
#
# Sending records 625219200.0|10.0|Regular insulin dose|1.0
#
# Sending records 625356000.0|14.0|Regular insulin dose|1.0
#
# Sending records 625494600.0|4.0|Regular insulin dose|1.0
#
# Sending records 625579200.0|10.0|Regular insulin dose|1.0
#
# Sending records 625600800.0|156.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 625665600.0|141.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 625838400.0|8.0|Regular insulin dose|1.0
#
# Sending records 625874400.0|10.0|Regular insulin dose|1.0
#
# Sending records 625874400.0|166.0|Unspecified blood glucose measurement|0.0
#
# Sending records 625905000.0|118.0|Unspecified blood glucose measurement|0.0
#
# Sending records 625910400.0|127.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 625959000.0|0.0|Typical meal ingestion|1.0
# Sending records 625960800.0|14.0|Regular insulin dose|1.0
#
# Sending records 625960800.0|184.0|Unspecified blood glucose measurement|0.0
#
# Sending records 625993200.0|5.0|Regular insulin dose|1.0
#
# Sending records 625996800.0|12.0|Regular insulin dose|1.0
#
# Sending records 626011200.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626011200.0|8.0|Regular insulin dose|1.0
#
# Sending records 626119200.0|15.0|Regular insulin dose|1.0
#
# Sending records 626119200.0|18.0|NPH insulin dose|1.0
#
# Sending records 626198400.0|0.0|Typical exercise activity|1.0
#
# Sending records 626205600.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626216400.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626252400.0|141.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626270400.0|6.0|Regular insulin dose|1.0
#
# Sending records 626270400.0|8.0|Regular insulin dose|1.0
#
# Sending records 626288400.0|199.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626293800.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626306400.0|135.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626306400.0|348.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626371200.0|110.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 626378400.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626477400.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626481000.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626510700.0|26.0|UltraLente insulin dose|1.0
#
# Sending records 626513400.0|0.0|Typical meal ingestion|1.0
#
# Sending records 626565600.0|10.0|Regular insulin dose|1.0
#
# Sending records 626616900.0|12.0|Regular insulin dose|1.0
#
# Sending records 626629500.0|226.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626637600.0|184.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626652000.0|14.0|Regular insulin dose|1.0
#
# Sending records 626652000.0|147.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626702400.0|4.0|Regular insulin dose|1.0
#
# Sending records 626724000.0|12.0|Regular insulin dose|1.0
#
# Sending records 626740200.0|116.0|Unspecified blood glucose measurement|0.0
#
# Sending records 626959800.0|180.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 626985000.0|172.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 626997600.0|134.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627048000.0|0.0|Typical meal ingestion|1.0
#
# Sending records 627135300.0|0.0|Typical meal ingestion|1.0
#
# Sending records 627206400.0|10.0|Regular insulin dose|1.0
#
# Sending records 627220800.0|160.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 627375600.0|247.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 627377400.0|26.0|UltraLente insulin dose|1.0
#
# Sending records 627379200.0|88.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 627393600.0|4.0|Regular insulin dose|1.0
#
# Sending records 627414300.0|223.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627415200.0|10.0|Regular insulin dose|1.0
#
# Sending records 627415200.0|178.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 627478200.0|14.0|Regular insulin dose|1.0
#
# Sending records 627480000.0|4.0|Regular insulin dose|1.0
#
# Sending records 627501600.0|10.0|Regular insulin dose|1.0
#
# Sending records 627516000.0|14.0|Regular insulin dose|1.0
#
# Sending records 627546600.0|26.0|UltraLente insulin dose|1.0
#
# Sending records 627549300.0|0.0|Typical meal ingestion|1.0
#
# Sending records 627636600.0|0.0|Typical meal ingestion|1.0
#
# Sending records 627672600.0|6.0|Regular insulin dose|1.0
#
# Sending records 627672600.0|193.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627723000.0|0.0|Typical meal ingestion|1.0
#
# Sending records 627760800.0|6.0|Regular insulin dose|1.0
#
# Sending records 627775200.0|204.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627812100.0|26.0|UltraLente insulin dose|1.0
#
# Sending records 627825600.0|14.0|Regular insulin dose|1.0
#
# Sending records 627903000.0|284.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627933600.0|189.0|Unspecified blood glucose measurement|0.0
#
# Sending records 627948000.0|364.0|Unspecified blood glucose measurement|0.0
#
# Sending records 628018200.0|6.0|Regular insulin dose|1.0
#
# Sending records 628120800.0|279.0|Unspecified blood glucose measurement|0.0
#
# Sending records 628155000.0|16.0|NPH insulin dose|1.0
#
# Sending records 628156800.0|12.0|Regular insulin dose|1.0
#
# Sending records 628257600.0|133.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 628257600.0|147.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 628365600.0|344.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 628466400.0|193.0|Unspecified blood glucose measurement|0.0
#
# Sending records 628675200.0|163.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 628711200.0|67.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 628812000.0|14.0|Regular insulin dose|1.0
#
# Sending records 628884000.0|176.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 628934400.0|12.0|Regular insulin dose|1.0
#
# Sending records 628934400.0|302.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 628968600.0|154.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 629019000.0|6.0|Regular insulin dose|1.0
#
# Sending records 629103600.0|6.0|Regular insulin dose|1.0
#
# Sending records 629143200.0|180.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 629157600.0|14.0|Regular insulin dose|1.0
#
# Sending records 629244000.0|14.0|Regular insulin dose|1.0
#
# Sending records 629244000.0|249.0|Unspecified blood glucose measurement|0.0
#
# Sending records 629467200.0|265.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 629553600.0|142.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 629589600.0|101.0|Unspecified blood glucose measurement|0.0
#
# Sending records 629658000.0|6.0|Regular insulin dose|1.0
#
# Sending records 629735400.0|4.0|Regular insulin dose|1.0
#
# Sending records 629735400.0|165.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 629762400.0|240.0|Unspecified blood glucose measurement|0.0
#
# Sending records 629834400.0|12.0|Regular insulin dose|1.0
#
# Sending records 630180000.0|14.0|Regular insulin dose|1.0
#
# Sending records 630230400.0|237.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 630264600.0|6.0|Regular insulin dose|1.0
#
# Sending records 630280800.0|14.0|Regular insulin dose|1.0
#
# Sending records 630331200.0|4.0|Regular insulin dose|1.0
#
# Sending records 630504000.0|4.0|Regular insulin dose|1.0
#
# Sending records 630540000.0|129.0|Unspecified blood glucose measurement|0.0
#
# Sending records 630590400.0|75.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 630626400.0|16.0|Regular insulin dose|1.0
#
# Sending records 630626400.0|136.0|Unspecified blood glucose measurement|0.0
#
# ...
#
# Sending records 679651200.0|126.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679668350.0|3.0|Regular insulin dose|1.0
#
# Sending records 679668700.0|189.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679684000.0|7.0|Regular insulin dose|1.0
#
# Sending records 679687200.0|97.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 679700160.0|45.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 679700300.0|5.0|NPH insulin dose|1.0
#
# Sending records 679730400.0|2.0|Regular insulin dose|1.0
#
# Sending records 679737600.0|92.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679737600.0|301.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679746600.0|250.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679752000.0|74.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679752000.0|310.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679774800.0|158.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 679784960.0|4.0|Regular insulin dose|1.0
#
# Sending records 679788000.0|4.0|NPH insulin dose|1.0
#
# Sending records 679819500.0|172.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679824000.0|7.0|Regular insulin dose|1.0
#
# Sending records 679824000.0|20.0|UltraLente insulin dose|1.0
#
# Sending records 679824000.0|46.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679824000.0|199.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 679838400.0|266.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679841100.0|0.0|Hypoglycemic symptoms|1.0
#
# Sending records 679924800.0|59.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 679941200.0|47.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 679945600.0|195.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 679958300.0|6.0|NPH insulin dose|1.0
# Sending records 680011200.0|10.0|Regular insulin dose|1.0
#
# Sending records 680011200.0|191.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680043970.0|172.0|Post-supper blood glucose measurement|0.0
#
# Sending records 680044160.0|2.0|Regular insulin dose|1.0
#
# Sending records 680047200.0|44.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680048260.0|6.0|NPH insulin dose|1.0
#
# Sending records 680077200.0|94.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680079170.0|190.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680081100.0|168.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680097600.0|8.0|Regular insulin dose|1.0
#
# Sending records 680133600.0|15.0|NPH insulin dose|1.0
#
# Sending records 680152300.0|46.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680166100.0|16.0|NPH insulin dose|1.0
#
# Sending records 680166850.0|5.0|Regular insulin dose|1.0
#
# Sending records 680169600.0|80.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680184000.0|3.0|Regular insulin dose|1.0
#
# Sending records 680184000.0|137.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680184600.0|87.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680205600.0|113.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 680217000.0|6.0|NPH insulin dose|1.0
#
# Sending records 680247000.0|24.0|NPH insulin dose|1.0
#
# Sending records 680256000.0|6.0|Regular insulin dose|1.0
#
# Sending records 680287800.0|10.0|Regular insulin dose|1.0
#
# Sending records 680290400.0|1.0|NPH insulin dose|1.0
#
# Sending records 680290750.0|179.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 680291650.0|3.0|Regular insulin dose|1.0
#
# Sending records 680307000.0|7.0|NPH insulin dose|1.0
#
# Sending records 680357250.0|64.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680373600.0|12.0|Regular insulin dose|1.0
#
# Sending records 680426500.0|6.0|Regular insulin dose|1.0
#
# Sending records 680428800.0|150.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680443200.0|3.0|Regular insulin dose|1.0
#
# Sending records 680464800.0|6.0|Regular insulin dose|1.0
#
# Sending records 680479040.0|159.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 680479300.0|2.0|Regular insulin dose|1.0
#
# Sending records 680515200.0|3.0|Regular insulin dose|1.0
#
# Sending records 680529600.0|115.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680551200.0|9.0|Regular insulin dose|1.0
#
# Sending records 680560450.0|237.0|Post-supper blood glucose measurement|0.0
#
# Sending records 680560640.0|6.0|NPH insulin dose|1.0
#
# Sending records 680565600.0|303.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680610370.0|14.0|Regular insulin dose|1.0
#
# Sending records 680616000.0|3.0|Regular insulin dose|1.0
#
# Sending records 680652300.0|244.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 680719200.0|339.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680721100.0|2.0|NPH insulin dose|1.0
#
# Sending records 680724000.0|6.0|Regular insulin dose|1.0
#
# Sending records 680724000.0|9.0|Regular insulin dose|1.0
#
# Sending records 680727600.0|10.0|Regular insulin dose|1.0
#
# Sending records 680768700.0|10.0|Regular insulin dose|1.0
#
# Sending records 680770800.0|7.0|Regular insulin dose|1.0
#
# Sending records 680774100.0|87.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 680788500.0|202.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680790200.0|3.0|Regular insulin dose|1.0
#
# Sending records 680806900.0|293.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 680823200.0|12.0|Regular insulin dose|1.0
#
# Sending records 680824800.0|2.0|Regular insulin dose|1.0
#
# Sending records 680824800.0|130.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680825700.0|3.0|Regular insulin dose|1.0
#
# Sending records 680860800.0|27.0|NPH insulin dose|1.0
#
# Sending records 680896800.0|7.0|Regular insulin dose|1.0
#
# Sending records 680911200.0|374.0|Unspecified blood glucose measurement|0.0
#
# Sending records 680913540.0|408.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 680940400.0|3.0|Regular insulin dose|1.0
#
# Sending records 680941200.0|7.0|Regular insulin dose|1.0
#
# Sending records 680960060.0|157.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680961600.0|149.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 680983500.0|7.0|Regular insulin dose|1.0
#
# Sending records 681017200.0|43.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681027800.0|338.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681033600.0|145.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681046400.0|57.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 681067700.0|1.0|NPH insulin dose|1.0
#
# Sending records 681070500.0|12.0|Regular insulin dose|1.0
#
# Sending records 681112770.0|20.0|NPH insulin dose|1.0
#
# Sending records 681120000.0|5.0|Regular insulin dose|1.0
#
# Sending records 681134400.0|3.0|Regular insulin dose|1.0
#
# Sending records 681137340.0|152.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 681142300.0|188.0|Post-lunch blood glucose measurement|0.0
#
# Sending records 681154800.0|2.0|NPH insulin dose|1.0
#
# Sending records 681154800.0|4.0|Regular insulin dose|1.0
#
# Sending records 681156000.0|14.0|Regular insulin dose|1.0
#
# Sending records 681156160.0|22.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681205200.0|24.0|NPH insulin dose|1.0
#
# Sending records 681242240.0|10.0|Regular insulin dose|1.0
#
# Sending records 681253000.0|2.0|Regular insulin dose|1.0
#
# Sending records 681256800.0|97.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681291600.0|84.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681309100.0|9.0|Regular insulin dose|1.0
#
# Sending records 681323500.0|5.0|Regular insulin dose|1.0
#
# Sending records 681328800.0|179.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 681373500.0|16.0|UltraLente insulin dose|1.0
#
# Sending records 681375300.0|24.0|NPH insulin dose|1.0
#
# Sending records 681393150.0|6.0|Regular insulin dose|1.0
#
# Sending records 681413250.0|4.0|Regular insulin dose|1.0
#
# Sending records 681415200.0|6.0|Regular insulin dose|1.0
#
# Sending records 681415200.0|171.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 681429600.0|15.0|NPH insulin dose|1.0
#
# Sending records 681435000.0|0.0|Hypoglycemic symptoms|1.0
#
# Sending records 681461100.0|44.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681465600.0|5.0|Regular insulin dose|1.0
#
# Sending records 681480000.0|3.0|Regular insulin dose|1.0
#
# Sending records 681480000.0|8.0|Regular insulin dose|1.0
#
# Sending records 681480000.0|119.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 681480000.0|141.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 681500800.0|3.0|Regular insulin dose|1.0
#
# Sending records 681501600.0|6.0|Regular insulin dose|1.0
#
# Sending records 681516000.0|100.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681552000.0|2.0|Regular insulin dose|1.0
#
# Sending records 681564900.0|7.0|Regular insulin dose|1.0
#
# Sending records 681585860.0|170.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 681588000.0|6.0|Regular insulin dose|1.0
#
# Sending records 681602400.0|113.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681674400.0|99.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 681722700.0|24.0|NPH insulin dose|1.0
#
# Sending records 681739200.0|9.0|Regular insulin dose|1.0
#
# Sending records 681760800.0|228.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 681808500.0|16.0|UltraLente insulin dose|1.0
#
# Sending records 681847200.0|6.0|Regular insulin dose|1.0
#
# Sending records 681861600.0|401.0|Unspecified blood glucose measurement|0.0
#
# Sending records 681947970.0|228.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 681984000.0|109.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681985200.0|129.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 681998400.0|7.0|Regular insulin dose|1.0
#
# Sending records 682030300.0|72.0|Pre-snack blood glucose measurement|0.0
#
# Sending records 682083600.0|5.0|Regular insulin dose|1.0
# Sending records 682083600.0|97.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 682106400.0|185.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 682110340.0|6.0|Regular insulin dose|1.0
#
# Sending records 682192800.0|8.0|Regular insulin dose|1.0
#
# Sending records 682236600.0|24.0|NPH insulin dose|1.0
#
# Sending records 682236600.0|246.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 682243200.0|5.0|Regular insulin dose|1.0
#
# Sending records 682243200.0|191.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 682244100.0|9.0|Regular insulin dose|1.0
#
# Sending records 682257600.0|3.0|Regular insulin dose|1.0
#
# Sending records 682279200.0|125.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 682293600.0|79.0|Unspecified blood glucose measurement|0.0
#
# Sending records 682329600.0|42.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 682344000.0|3.0|Regular insulin dose|1.0
#
# Sending records 682381200.0|309.0|Unspecified blood glucose measurement|0.0
#
# Sending records 682435600.0|12.0|Regular insulin dose|1.0
#
# Sending records 682502400.0|15.0|NPH insulin dose|1.0
#
# Sending records 682537500.0|10.0|Regular insulin dose|1.0
#
# Sending records 682538400.0|4.0|Regular insulin dose|1.0
#
# Sending records 682581500.0|304.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 682603200.0|3.0|Regular insulin dose|1.0
#
# Sending records 682624800.0|12.0|Regular insulin dose|1.0
#
# Sending records 682667800.0|6.0|Regular insulin dose|1.0
#
# Sending records 682717500.0|85.0|Unspecified blood glucose measurement|0.0
#
# Sending records 682761600.0|3.0|Regular insulin dose|1.0
#
# Sending records 682797600.0|171.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 682843500.0|24.0|NPH insulin dose|1.0
#
# Sending records 682862100.0|68.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 682924800.0|6.0|Regular insulin dose|1.0
#
# Sending records 682924800.0|227.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 682928700.0|15.0|NPH insulin dose|1.0
#
# Sending records 682934400.0|3.0|Regular insulin dose|1.0
#
# Sending records 682961200.0|266.0|Unspecified blood glucose measurement|0.0
#
# Sending records 682970400.0|226.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 682985200.0|103.0|Unspecified blood glucose measurement|0.0
#
# Sending records 683071200.0|15.0|NPH insulin dose|1.0
#
# Sending records 683112600.0|4.0|Regular insulin dose|1.0
#
# Sending records 683113800.0|293.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 683123460.0|4.0|Regular insulin dose|1.0
#
# Sending records 683143200.0|155.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 683148600.0|12.0|Regular insulin dose|1.0
#
# Sending records 683208000.0|4.0|Regular insulin dose|1.0
#
# Sending records 683230600.0|112.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 683244000.0|148.0|Unspecified blood glucose measurement|0.0
#
# Sending records 683356800.0|24.0|NPH insulin dose|1.0
#
# Sending records 683360300.0|307.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 683380800.0|183.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 683396900.0|11.0|Regular insulin dose|1.0
#
# Sending records 683445100.0|16.0|UltraLente insulin dose|1.0
#
# Sending records 683449500.0|4.0|Regular insulin dose|1.0
#
# Sending records 683467200.0|96.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 683503200.0|15.0|NPH insulin dose|1.0
#
# Sending records 683539200.0|230.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 683543040.0|253.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 683554200.0|5.0|Regular insulin dose|1.0
#
# Sending records 683589600.0|15.0|NPH insulin dose|1.0
#
# Sending records 683625600.0|2.0|Regular insulin dose|1.0
#
# Sending records 683661200.0|113.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 683661600.0|8.0|Regular insulin dose|1.0
#
# Sending records 683663700.0|249.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 683676000.0|149.0|Unspecified blood glucose measurement|0.0
#
# Sending records 683746900.0|7.0|Regular insulin dose|1.0
#
# Sending records 683798400.0|41.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 683802000.0|24.0|NPH insulin dose|1.0
#
# Sending records 683816400.0|4.0|Regular insulin dose|1.0
#
# Sending records 683834400.0|9.0|Regular insulin dose|1.0
#
# Sending records 683965500.0|4.0|Regular insulin dose|1.0
#
# Sending records 683965500.0|24.0|NPH insulin dose|1.0
#
# Sending records 683985300.0|5.0|Regular insulin dose|1.0
#
# Sending records 684028740.0|113.0|Unspecified blood glucose measurement|0.0
#
# Sending records 684051600.0|3.0|Regular insulin dose|1.0
#
# Sending records 684072000.0|101.0|Pre-lunch blood glucose measurement|0.0
#
# Sending records 684267300.0|10.0|Regular insulin dose|1.0
#
# Sending records 684361200.0|43.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 684486000.0|195.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 684568200.0|24.0|NPH insulin dose|1.0
#
# Sending records 684568200.0|70.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 684655200.0|24.0|NPH insulin dose|1.0
#
# Sending records 684831900.0|3.0|Regular insulin dose|1.0
#
# Sending records 685004100.0|267.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 685308600.0|13.0|Regular insulin dose|1.0
#
# Sending records 685358400.0|24.0|NPH insulin dose|1.0
#
# Sending records 685394400.0|326.0|Pre-supper blood glucose measurement|0.0
#
# Sending records 685416300.0|209.0|Unspecified blood glucose measurement|0.0
#
# Sending records 685443900.0|8.0|Regular insulin dose|1.0
#
# Sending records 685577700.0|3.0|Regular insulin dose|1.0
#
# Sending records 685611900.0|8.0|Regular insulin dose|1.0
#
# Sending records 685611900.0|265.0|Pre-breakfast blood glucose measurement|0.0
#
# Sending records 685660200.0|2.0|Regular insulin dose|1.0
# End Of Streaming.
